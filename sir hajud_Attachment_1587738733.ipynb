# %%
import pandas as pd
import matplotlib.pyplot as plt
#reading data file and get create dataframe
df = pd.read_excel("Attachment_1587738739.xlsx")

# %%
df
# Out:
#      Location       Date  Average Property Prices that year  Total Crime  \
# 0           1 2019-10-01                           556392.0          166
# 1           1 2019-09-01                           556392.0          202
# 2           1 2019-08-01                           556392.0          202
# 3           1 2019-07-01                           556392.0          226
# 4           1 2019-06-01                           556392.0          187
# ..        ...        ...                                ...          ...
# 307         4 2013-09-01                           799449.0          233
# 308         4 2013-08-01                           799449.0          234
# 309         4 2013-07-01                           799449.0          250
# 310         4 2013-06-01                           799449.0          218
# 311         4 2013-05-01                           799449.0          190
#
#      Total Schools  % Change in overall property price from previous year  \
# ...

# %%
#filtering data set to get only rows which has location 3
mask = (df['Location'] ==3)
df1=df.loc[mask]

#ploting data 
ax = plt.gca()
df1.plot(kind='line',x='Date',y='Average Property Prices that year')
df1.plot(kind='line',x='Date',y='Total Crime', color='red', ax=ax)
plt.show()

# %%
#filtering data set to get only rows which has location 4
mask = (df['Location'] ==4)
df1=df.loc[mask]

#ploting data 
ax = plt.gca()
df1.plot(kind='line',x='Date',y='Average Property Prices that year')
df1.plot(kind='line',x='Date',y='Total Crime', color='red', ax=ax)
plt.show()

# %%
df4=df[['Robbery','Average Property Prices that year','Date']]
df4.head()
# Out:
#    Robbery  Average Property Prices that year       Date
# 0        2                           556392.0 2019-10-01
# 1       10                           556392.0 2019-09-01
# 2        7                           556392.0 2019-08-01
# 3        7                           556392.0 2019-07-01
# 4        3                           556392.0 2019-06-01

# %%
ax = plt.gca()
df4.plot(kind='line',x='Date',y='Average Property Prices that year')
df4.plot(kind='line',x='Date',y='Robbery', color='red', ax=ax)
plt.show()

# %%
df4.describe()
# Out:
#           Robbery  Average Property Prices that year
# count  312.000000                       3.120000e+02
# mean    16.733974                       1.006189e+06
# std     21.473301                       6.651300e+05
# min      0.000000                       3.182870e+05
# 25%      4.000000                       4.916330e+05
# 50%      7.000000                       6.835350e+05
# 75%     21.500000                       1.391234e+06
# max     96.000000                       2.328846e+06

# %%
df.describe()
# Out:
#         Location  Average Property Prices that year  Total Crime  \
# count  312.00000                       3.120000e+02   312.000000
# mean     2.50000                       1.006189e+06   660.262821
# std      1.11983                       6.651300e+05   839.788004
# min      1.00000                       3.182870e+05    87.000000
# 25%      1.75000                       4.916330e+05   153.750000
# 50%      2.50000                       6.835350e+05   204.000000
# 75%      3.25000                       1.391234e+06   651.750000
# max      4.00000                       2.328846e+06  2997.000000
#
#        Total Schools  % Change in overall property price from previous year  \
# count     312.000000                                         312.000000
# mean       25.000000                                           7.141356
# std        19.240231                                           7.782604
# min         8.000000                                         -10.152649
# ...

# %%
df.corr()
# Out:
#                                                     Location  \
# Location                                            1.000000
# Average Property Prices that year                   0.516206
# Total Crime                                         0.278233
# Total Schools                                       0.582025
# % Change in overall property price from previou... -0.048882
# Average wage 2019                                   0.292992
# ASB                                                 0.270272
# Burglary                                            0.289816
# Robbery                                             0.196364
# Vehicle                                             0.304595
# Violent                                             0.219324
# Shoplifting                                         0.387469
# CD&A                                                0.277925
# Other Theft                                         0.292771
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# from sklearn.linear_model import LinearRegression
# lm=LinearRegression()
# import seaborn as sns

# X=df[['Robbery','Date','ASB','Vehicle','Violent','Shoplifting']]
# #Y=df['Average Property Prices that year']
# lm.fit(X, df['Average Property Prices that year'])
# yhat=lm.predict(X)
# ax2=sns.distplot(df['Average Property Prices that year'],hist=False,color='r',label='Actual_value')
# sns.distplot(Yhat,hist=False,color='b',label='Fitted_values',ax=ax2)
# plt.xlabel('kuxh b')
# plt.ylabel('nothing')
# plt.show()
# plt.close()

# %%
# But I wish to show regression between the individual crimes 
# and the property price in the same bit of data as I’ve done before with total crime and property prices.
# 2
# Right now you see the total crime is showed in comparison with average property price
# 3.
# What I want now is
# ASB Burglary Robbery Vehicle Violent Shoplifting CD&A Other Theft Drugs Bike Theft
# Theft From the Person Weapons Public Order Other, All individually regressed to show the specific crime 
# effect on property price.
# So I should be able to look at the programming and see for example how much drugs effect property price
# 4
# I would like individual graph for each variable; and then a big graph at the end to show comparison between variables
# 5.
# Yes, what I want to see is the the regression output for total crime/ and average property price on a graph
# 6.

# %%
df5=df[['Robbery','Date','ASB','Vehicle','Violent','Shoplifting','Average Property Prices that year','CD&A','Other Theft','Drugs','Bike Theft','Theft From the Person','Weapons','Public Order','Other']]
df5.corr()
# Out:
#                                     Robbery       ASB   Vehicle   Violent  \
# Robbery                            1.000000  0.874323  0.905428  0.926444
# ASB                                0.874323  1.000000  0.919001  0.925242
# Vehicle                            0.905428  0.919001  1.000000  0.953601
# Violent                            0.926444  0.925242  0.953601  1.000000
# Shoplifting                        0.842901  0.950880  0.947851  0.930761
# Average Property Prices that year  0.846741  0.908698  0.937231  0.910498
# CD&A                               0.890389  0.945161  0.959273  0.960429
# Other Theft                        0.877824  0.975219  0.932305  0.926824
# Drugs                              0.795892  0.766316  0.753398  0.839628
# Bike Theft                         0.842854  0.927282  0.879790  0.876587
# Theft From the Person              0.885790  0.861578  0.808853  0.857557
# Weapons                            0.696658  0.650118  0.655532  0.768837
# ...

# %%
df5=df[['Robbery','Date','ASB','Vehicle','Violent','Shoplifting','Average Property Prices that year','CD&A','Other Theft','Drugs','Bike Theft','Theft From the Person','Weapons','Public Order','Other']]
df5.corr()
# Out:
#                                     Robbery       ASB   Vehicle   Violent  \
# Robbery                            1.000000  0.874323  0.905428  0.926444
# ASB                                0.874323  1.000000  0.919001  0.925242
# Vehicle                            0.905428  0.919001  1.000000  0.953601
# Violent                            0.926444  0.925242  0.953601  1.000000
# Shoplifting                        0.842901  0.950880  0.947851  0.930761
# Average Property Prices that year  0.846741  0.908698  0.937231  0.910498
# CD&A                               0.890389  0.945161  0.959273  0.960429
# Other Theft                        0.877824  0.975219  0.932305  0.926824
# Drugs                              0.795892  0.766316  0.753398  0.839628
# Bike Theft                         0.842854  0.927282  0.879790  0.876587
# Theft From the Person              0.885790  0.861578  0.808853  0.857557
# Weapons                            0.696658  0.650118  0.655532  0.768837
# ...

# %%
sns.pairplot(df)

# %%
import matplotlib.pyplot as pls 
ax = plt.gca()

df.plot(x='Date', y='Average Property Prices that year', kind='line',ax=ax) 
plt.show()

# %%
# df.plot(y=['Date','Average Property Prices that year'], kind="bar")

# %%
import pandas as pd
from sklearn import linear_model
import tkinter as tk 
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

# %%
X = df[['Robbery','Vehicle']].astype(float) # here we have 2 input variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y = df['Average Property Prices that year'].astype(float) # output variable (what we are trying to predict)

# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# tkinter GUI
root= tk.Tk()

canvas1 = tk.Canvas(root, width = 500, height = 300)
canvas1.pack()

# with sklearn
Intercept_result = ('Intercept: ', regr.intercept_)
label_Intercept = tk.Label(root, text=Intercept_result, justify = 'center')
canvas1.create_window(260, 220, window=label_Intercept)

# with sklearn
Coefficients_result  = ('Coefficients: ', regr.coef_)
label_Coefficients = tk.Label(root, text=Coefficients_result, justify = 'center')
canvas1.create_window(260, 240, window=label_Coefficients)

# New_Interest_Rate label and input box
label1 = tk.Label(root, text='Type Robbery: ')
canvas1.create_window(100, 100, window=label1)

entry1 = tk.Entry (root) # create 1st entry box
canvas1.create_window(270, 100, window=entry1)

# New_Unemployment_Rate label and input box
label2 = tk.Label(root, text=' Type Vehicle: ')
canvas1.create_window(120, 120, window=label2)

entry2 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 120, window=entry2)

def values(): 
    global Robbery #our 1st input variable
    Robbery = float(entry1.get()) 
    
    global Vehicle #our 2nd input variable
    Vehicle = float(entry2.get()) 
    
    Prediction_result  = ('Predicted Stock Index Price: ', regr.predict([[Robbery ,Vehicle]]))
    label_Prediction = tk.Label(root, text= Prediction_result, bg='orange')
    canvas1.create_window(260, 280, window=label_Prediction)
    
button1 = tk.Button (root, text='Average Property Prices that year',command=values, bg='orange') # button to call the 'values' command above 
canvas1.create_window(270, 150, window=button1)
 
#plot 1st scatter 
figure3 = plt.Figure(figsize=(5,4), dpi=100)
ax3 = figure3.add_subplot(111)
ax3.scatter(df['Robbery'].astype(float),df['Average Property Prices that year'].astype(float), color = 'r')
scatter3 = FigureCanvasTkAgg(figure3, root) 
scatter3.get_tk_widget().pack(side=tk.RIGHT, fill=tk.BOTH)
ax3.legend(['Average Property Prices that year']) 
ax3.set_xlabel('Robbery')
ax3.set_title('Robbery Vs.  Price')

#plot 2nd scatter 
figure4 = plt.Figure(figsize=(5,4), dpi=100)
ax4 = figure4.add_subplot(111)
ax4.scatter(df['Vehicle'].astype(float),df['Average Property Prices that year'].astype(float), color = 'g')
scatter4 = FigureCanvasTkAgg(figure4, root) 
scatter4.get_tk_widget().pack(side=tk.RIGHT, fill=tk.BOTH)
ax4.legend(['Average Property Prices that year']) 
ax4.set_xlabel('Vehicle')
ax4.set_title('Vehicle Vs.  Price')

root.mainloop()
# Out:
# Intercept:
#  546476.8644529968
# Coefficients:
#  [-318.75124553 6637.44357473]

# %%
df['date'] = pd.DatetimeIndex(df['Date']).year
del df['Date']

df.head(10)
# Out:
#    Location  Average Property Prices that year  Total Crime  Total Schools  \
# 0         1                           556392.0          166              8
# 1         1                           556392.0          202              8
# 2         1                           556392.0          202              8
# 3         1                           556392.0          226              8
# 4         1                           556392.0          187              8
# 5         1                           556392.0          227              8
# 6         1                           556392.0          181              8
# 7         1                           556392.0          214              8
# 8         1                           556392.0          196              8
# 9         1                           556392.0          184              8
#
#    % Change in overall property price from previous year  Average wage 2019  \
# ...

# %%
from numpy import std
from pandas import DataFrame
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
# Out:
#   File "<ipython-input-56-ac04653af86d>", line 3
#     g=sns.catplot(x="Robbery", y="Average Property Prices that year",hue="date",
#     ^
# SyntaxError: invalid syntax

# %%
# bar graph
df.plot.hist(x='date', y='Average Property Prices that year' , colormap='Pastel2', title='Avg price with date')
plt.gcf().set_size_inches(7, 5)
plt.show()

# %%
# sql queryy
query_1 = '''SELECT Sum("Robbery") as total_robery , "date","Average Property Prices that year" FROM df group by "date";'''
res_1 = pysqldf(query_1)
res_1
# Out:
#    total_robery  date  Average Property Prices that year
# 0           520  2013                           387330.0
# 1           587  2014                           453804.0
# 2           569  2015                           498778.0
# 3           687  2016                           549066.0
# 4           895  2017                           549163.0
# 5           972  2018                           567621.0
# 6           991  2019                           556392.0

# %%
# bar graph
res_1.plot.bar(x='date', y='Average Property Prices that year' , colormap='Pastel2', title='Robery details per year')
plt.gcf().set_size_inches(7, 5)
plt.show()

# %%
# sql queryy
query_2 = '''SELECT Sum("Vehicle") as vehicle_count , "date","Average Property Prices that year" FROM df group by "date";'''
res_2 = pysqldf(query_1)
res_2
# Out:
#    total_robery  date  Average Property Prices that year
# 0           520  2013                           387330.0
# 1           587  2014                           453804.0
# 2           569  2015                           498778.0
# 3           687  2016                           549066.0
# 4           895  2017                           549163.0
# 5           972  2018                           567621.0
# 6           991  2019                           556392.0

# %%
# bar graph
res_2.plot.bar(x='date', y='Average Property Prices that year' , colormap='Pastel2', title='vehicle details per year')
plt.gcf().set_size_inches(7, 5)
plt.show()

# %%
res_2.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000239751A2288>,
# ...
#       dtype=object)

# %%
df.describe()
# Out:
#         Location  Average Property Prices that year  Total Crime  \
# count  312.00000                       3.120000e+02   312.000000
# mean     2.50000                       1.006189e+06   660.262821
# std      1.11983                       6.651300e+05   839.788004
# min      1.00000                       3.182870e+05    87.000000
# 25%      1.75000                       4.916330e+05   153.750000
# 50%      2.50000                       6.835350e+05   204.000000
# 75%      3.25000                       1.391234e+06   651.750000
# max      4.00000                       2.328846e+06  2997.000000
#
#        Total Schools  % Change in overall property price from previous year  \
# count     312.000000                                         312.000000
# mean       25.000000                                           7.141356
# std        19.240231                                           7.782604
# min         8.000000                                         -10.152649
# ...

# %%
pip install plotly
# Out:
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-cp37-none-any.whl size=11435 sha256=d4597188e3cb5ff594138cd8f4f0d2e5d7c2b468c9498360c814298ea3a07a9c
#   Stored in directory: C:\Users\Hamxa\AppData\Local\pip\Cache\wheels\d7\a9\33\acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c
# Successfully built retrying
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import plotly.express as px
fig = px.bar(df, x = 'date', y = 'Average Property Prices that year')
fig.show()
# Out:
# <div>
#
#
#             <div id="0df20ba6-b6bc-4675-b5c1-6706872734cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0df20ba6-b6bc-4675-b5c1-6706872734cc")) {
#                     Plotly.newPlot(
#                         '0df20ba6-b6bc-4675-b5c1-6706872734cc',
# ...

# %%
import pandas as pd
import plotly.graph_objs as go

fig = go.Figure()
fig.add_trace(go.Bar(x=df.index,
                     y=df["Average Property Prices that year"],
                     name="Position"))
fig.add_trace(go.Bar(x=df.index,
                     y=df["Robbery"],
                     name="Score"))

fig.update_layout(
    xaxis = dict(
        tickmode = 'array',
        tickvals = df.index,
        ticktext = df["date"])
)
# Out:
# <div>
#
#
#             <div id="2206df05-72ec-4059-bc3f-ffee43125898" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2206df05-72ec-4059-bc3f-ffee43125898")) {
#                     Plotly.newPlot(
#                         '2206df05-72ec-4059-bc3f-ffee43125898',
# ...

# %%
import pandas as pd
from plotly.subplots import make_subplots
import plotly.graph_objs as go

fig = make_subplots(rows=1, cols=2,
                    subplot_titles=["Robbery",
                                    "Average Property Prices that year"]
                   )
fig.add_trace(go.Bar(x=df.index,
                     y=df["Average Property Prices that year"],
                     name="Position"),
             row=1, col=1)
fig.add_trace(go.Bar(x=df.index,
                     y=df["Robbery"],
                     name="Score"),
             row=1, col=2)
fig['layout']['xaxis1'].update(dict(
        tickmode = 'array',
        tickvals = df.index,
        ticktext = df["date"]))

fig['layout']['xaxis2'].update(dict(
        tickmode = 'array',
        tickvals = df.index,
        ticktext = df["date"]))

fig.show()
# Out:
# <div>
#
#
#             <div id="2c5785da-2444-4a2a-bf30-2cbcd6c7d339" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2c5785da-2444-4a2a-bf30-2cbcd6c7d339")) {
#                     Plotly.newPlot(
#                         '2c5785da-2444-4a2a-bf30-2cbcd6c7d339',
# ...

# %%
df
# Out:
#      Location  Average Property Prices that year  Total Crime  Total Schools  \
# 0           1                           556392.0          166              8
# 1           1                           556392.0          202              8
# 2           1                           556392.0          202              8
# 3           1                           556392.0          226              8
# 4           1                           556392.0          187              8
# ..        ...                                ...          ...            ...
# 307         4                           799449.0          233             26
# 308         4                           799449.0          234             26
# 309         4                           799449.0          250             26
# 310         4                           799449.0          218             26
# 311         4                           799449.0          190             26
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312 entries, 0 to 311
# Data columns (total 21 columns):
# Location                                                 312 non-null int64
# Average Property Prices that year                        312 non-null float64
# Total Crime                                              312 non-null int64
# Total Schools                                            312 non-null int64
# % Change in overall property price from previous year    312 non-null float64
# Average wage 2019                                        312 non-null int64
# ASB                                                      312 non-null int64
# Burglary                                                 312 non-null int64
# Robbery                                                  312 non-null int64
# Vehicle                                                  312 non-null int64
# Violent                                                  312 non-null int64
# ...

# %%
df.describe()
# Out:
#         Location  Average Property Prices that year  Total Crime  \
# count  312.00000                       3.120000e+02   312.000000
# mean     2.50000                       1.006189e+06   660.262821
# std      1.11983                       6.651300e+05   839.788004
# min      1.00000                       3.182870e+05    87.000000
# 25%      1.75000                       4.916330e+05   153.750000
# 50%      2.50000                       6.835350e+05   204.000000
# 75%      3.25000                       1.391234e+06   651.750000
# max      4.00000                       2.328846e+06  2997.000000
#
#        Total Schools  % Change in overall property price from previous year  \
# count     312.000000                                         312.000000
# mean       25.000000                                           7.141356
# std        19.240231                                           7.782604
# min         8.000000                                         -10.152649
# ...

# %%
import pandas as pd
from sklearn import linear_model
import statsmodels.api as sm
# ,,,'',''
X = df[['Robbery','Bike Theft','Vehicle','Weapons','Public Order','Other','ASB','Violent','Shoplifting','Theft From the Person','CD&A','Other Theft','Drugs',]] # here we have many variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y = df['Average Property Prices that year']
 
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# prediction with sklearn
# New_Interest_Rate = 2.75
# New_Unemployment_Rate = 5.3
# print ('Predicted Stock Index Price: \n', regr.predict([[New_Interest_Rate ,New_Unemployment_Rate]]))

# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  533245.723641895
# Coefficients:
#  [ 1820.14232422  4871.84725416  1517.64718264  -386.86135709
#    703.87420672  -687.74181551 -1196.95280323  -613.49518783
#   8120.42141158   197.70537443  2338.63782472   655.22475251
#     92.45955947]
#                                     OLS Regression Results
# ...
# Dep. Variable:     Average Property Prices that year   R-squared:                       0.929
# Model:                                           OLS   Adj. R-squared:                  0.925
# Method:                                Least Squares   F-statistic:                     298.1
# Date:                               Sat, 25 Apr 2020   Prob (F-statistic):          3.81e-162
# Time:                                       14:51:56   Log-Likelihood:                -4213.7
# No. Observations:                                312   AIC:                             8455.
# Df Residuals:                                    298   BIC:                             8508.
# ...

# %%
# By showing direct coeficient and then by regression method our method is good, both are same.

# %%
# Now we will show all varibles corelation using heat map and simple statistical method

# %%
#statistical method
df.corr()
# Out:
#                                                     Location  \
# Location                                            1.000000
# Average Property Prices that year                   0.516206
# Total Crime                                         0.278233
# Total Schools                                       0.582025
# % Change in overall property price from previou... -0.048882
# Average wage 2019                                   0.292992
# ASB                                                 0.270272
# Burglary                                            0.289816
# Robbery                                             0.196364
# Vehicle                                             0.304595
# Violent                                             0.219324
# Shoplifting                                         0.387469
# CD&A                                                0.277925
# Other Theft                                         0.292771
# ...

# %%
corr = df5.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# corelation is good between variables when they are close to 1 and -1,
# so i graph one can see once we compare 'Average Property Prices that year wth all other variables' its good relation , its not less light or orange colur . look they are highly dependent on avg-price with strong relation

# %% [markdown]
# Now to show every relation of avg_price with specific crime to show relation

# %%
import pandas as pd
import matplotlib.pyplot as plt
   
plt.scatter(df['Average Property Prices that year'], df['Robbery'], color='red')
plt.title('Price Vs Robbery', fontsize=14)
plt.xlabel('Robbery', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
   
plt.scatter(df['Average Property Prices that year'], df['Vehicle'], color='black')
plt.title('Price Vs vehicle', fontsize=14)
plt.xlabel('vehicle', fontsize=14)
plt.ylabel('Avg_Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
   
plt.scatter(df['Average Property Prices that year'], df['Public Order'], color='Yellow')
plt.title('Price Vs Public Order', fontsize=14)
plt.xlabel('Public Order', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
   
plt.scatter(df['Average Property Prices that year'], df['Shoplifting'], color='brown')
plt.title('Price Vs Asb', fontsize=14)
plt.xlabel('Asb', fontsize=14)
plt.ylabel(' Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
   
plt.scatter(df['Average Property Prices that year'], df['Weapons'], color='purple')
plt.title('Price Vs Asb', fontsize=14)
plt.xlabel('Weapons', fontsize=14)
plt.ylabel(' Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
   
plt.scatter(df['Average Property Prices that year'], df['Shoplifting'], color='black')
plt.title('Price Vs Shoplifting', fontsize=14)
plt.xlabel('Shoplifting', fontsize=14)
plt.ylabel(' Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
   
plt.scatter(df['Average Property Prices that year'], df['Burglary'], color='green')
plt.title('Price Vs Burglary', fontsize=14)
plt.xlabel('Burglary', fontsize=14)
plt.ylabel(' Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
   
plt.scatter(df['Average Property Prices that year'], df['CD&A'], color='yellow')
plt.title('Price Vs CD&A   ', fontsize=14)
plt.xlabel('CD&A   ', fontsize=14)
plt.ylabel(' Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
   
plt.scatter(df['Average Property Prices that year'], df['Violent'], color='black')
plt.title('Price Vs Voilent', fontsize=14)
plt.xlabel('Voilent', fontsize=14)
plt.ylabel(' Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
   
plt.scatter(df['Average Property Prices that year'], df['Theft From the Person'], color='red')
plt.title('Price Vs Theft From the Person   ', fontsize=14)
plt.xlabel('Theft From the Person  ', fontsize=14)
plt.ylabel(' Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
   
plt.scatter(df['Average Property Prices that year'], df['Bike Theft'], color='pink')
plt.title('Price Vs Bike Theft   ', fontsize=14)
plt.xlabel('Bike Theft  ', fontsize=14)
plt.ylabel(' Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
#Now showing all varibles by pairplot with refrence to Avg_price

# %%
pp = sns.pairplot(data=df,
                  y_vars=['Average Property Prices that year'],
                  x_vars=['Robbery','date','ASB','Vehicle','Violent'])

# %%
pp = sns.pairplot(data=df,
                  y_vars=['Average Property Prices that year'],
                  x_vars=['Bike Theft','Weapons','Public Order','Other'])

# %%
pp = sns.pairplot(data=df,
                  y_vars=['Average Property Prices that year'],
                  x_vars=['Shoplifting','Theft From the Person','Drugs','CD&A','Other Theft'])

# %%
# we can show by bar graph

# %%
from numpy import std
from pandas import DataFrame
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
# sql queryy
query_1 = '''SELECT Sum("Robbery") as total_robery , "date","Average Property Prices that year" FROM df group by "date";'''
res_1 = pysqldf(query_1)
res_1
# Out:
#    total_robery  date  Average Property Prices that year
# 0           520  2013                           387330.0
# 1           587  2014                           453804.0
# 2           569  2015                           498778.0
# 3           687  2016                           549066.0
# 4           895  2017                           549163.0
# 5           972  2018                           567621.0
# 6           991  2019                           556392.0

# %%
# bar graph
res_1.plot.bar(x='date', y='Average Property Prices that year' , colormap='Pastel2', title='Robery details per year with avg_price')
plt.gcf().set_size_inches(7, 5)
plt.show()

# %%
# bar graph
res_1.plot.bar(x='date', y='total_robery' , colormap='Pastel2', title='total Number of Robery details per year')
plt.gcf().set_size_inches(7, 5)
plt.show()

# %%
# sql queryy
query_2 = '''SELECT Sum("Vehicle") as Vehicle_count , "date","Average Property Prices that year" FROM df group by "date";'''
res_2 = pysqldf(query_2)
res_2
# Out:
#    Vehicle_count  date  Average Property Prices that year
# 0           1678  2013                           387330.0
# 1           2827  2014                           453804.0
# 2           2936  2015                           498778.0
# 3           3534  2016                           549066.0
# 4           3823  2017                           549163.0
# 5           3662  2018                           567621.0
# 6           3400  2019                           556392.0

# %%
# bar graph
res_2.plot.bar(x='date', y='Average Property Prices that year' , colormap='Pastel2', title='vehicle details per year')
plt.gcf().set_size_inches(7, 5)
plt.show()

# %%
# bar graph
res_2.plot.bar(x='date', y='Vehicle_count' , colormap='Pastel2', title='vehicle details per year')
plt.gcf().set_size_inches(7, 5)
plt.show()

# %%
# sql queryy
query_3 = '''SELECT Sum("Violent") as Violent_count , "date","Average Property Prices that year" FROM df group by "date";'''
res_3 = pysqldf(query_3)
res_3
# Out:
#    Violent_count  date  Average Property Prices that year
# 0           2225  2013                           387330.0
# 1           4225  2014                           453804.0
# 2           4896  2015                           498778.0
# 3           5063  2016                           549066.0
# 4           5549  2017                           549163.0
# 5           5821  2018                           567621.0
# 6           4840  2019                           556392.0

# %%
# bar graph
res_3.plot.bar(x='date', y='Average Property Prices that year' , colormap='Pastel2', title='Voilent details per year')
plt.gcf().set_size_inches(7, 5)
plt.show()

# %%
# bar graph
res_3.plot.bar(x='date', y='Violent_count' , colormap='Pastel2', title='Total number of Volent details per year')
plt.gcf().set_size_inches(7, 5)
plt.show()
